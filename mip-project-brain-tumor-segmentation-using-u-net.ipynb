# %%
# Importing packages
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import time

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import backend as K
import tensorflow.keras.backend as K

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Path to the dataset
data_path = "/kaggle/input/brain-tumor-segmentation-dataset/Brain Tumor Segmentation Dataset"

# Tumor classes
classes = ['no_tumor', 'glioma_tumor', 'meningioma_tumor', 'pituitary_tumor']

# Initialize lists to store images, masks, and labels
images = []
masks = []
labels = []
# Desired size for images and masks
target_size = (128, 128)

# Load images and masks
for class_name in classes:
    image_folder = os.path.join(data_path, 'image', str(classes.index(class_name)))
    mask_folder = os.path.join(data_path, 'mask', str(classes.index(class_name)))
    
    # Check if the folders exist
    if os.path.exists(image_folder) and os.path.exists(mask_folder):
        # Load images
        for image_name in tqdm(os.listdir(image_folder), desc=class_name):
            if image_name.endswith('.jpg') or image_name.endswith('.png'):  # Check for image format
                image_path = os.path.join(image_folder, image_name)
                image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
                image = cv2.resize(image, target_size) 
                image = image / 255.0
                
                # Check for the corresponding mask name
                mask_name = image_name.replace('.jpg', '_m.jpg').replace('.png', '_m.png')
                mask_path = os.path.join(mask_folder, mask_name)

                # Load the mask only if it exists
                if os.path.exists(mask_path):
                    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                    mask = cv2.resize(mask, target_size) 
                    mask = mask / 255.0
                    
                    # Add images and masks to the lists
                    images.append(image)
                    masks.append(mask)
                    labels.append(classes.index(class_name))
                
                else:
                    print(f"Mask missing for image: {image_name}")

# Convert lists to NumPy arrays
images = np.array(images).reshape(-1, 128, 128, 1)
masks = np.array(masks).reshape(-1, 128, 128, 1)
labels = np.array(labels)

# Display the dimensions of the datasets
print(f"Number of images: {len(images)}, Number of masks: {len(masks)}, Number of labels: {len(labels)}")
# Out:
# no_tumor:   0%|          | 0/1595 [00:00<?, ?it/s]
# glioma_tumor:   0%|          | 0/649 [00:00<?, ?it/s]
# meningioma_tumor:   0%|          | 0/999 [00:00<?, ?it/s]
# pituitary_tumor:   0%|          | 0/994 [00:00<?, ?it/s]
# Number of images: 4237, Number of masks: 4237, Number of labels: 4237

# %%
# Count the number of images per class
unique, counts = np.unique(labels, return_counts=True)
class_counts = dict(zip(classes, counts))

# %%
# Count the number of images per class
unique, counts = np.unique(labels, return_counts=True)
class_counts = dict(zip(classes, counts))

# Calculate the total number of images and percentages
total_images = sum(class_counts.values())
percentages = [(count / total_images) * 100 for count in class_counts.values()]

# Create the bar chart
plt.figure(figsize=(8, 6))
bars = plt.bar(class_counts.keys(), class_counts.values(), color='skyblue')

# Add percentages above the bars
for bar, percentage in zip(bars, percentages):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{percentage:.1f}%', ha='center', va='bottom')

plt.xlabel('Tumor Classes')
plt.ylabel('Number of Images')
plt.title('Number of Images per Brain Tumor Class')
plt.grid(axis='y')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Initialize figure with a grid for 4 classes
fig, axs = plt.subplots(len(classes) + 1, 5, figsize=(10, 10), 
                         gridspec_kw={'width_ratios': [0.5, 4, 4, 4 ,4], 'height_ratios': [0.5, 4, 4, 4, 4]})

# Column titles
axs[0, 0].text(0.5, 0.5, "", fontsize=10, ha='center', va='center', fontweight='bold')
axs[0, 0].axis('off')  # Remove axes

axs[0, 1].text(0.5, 0.5, "MRI Image", fontsize=10, ha='center', va='center', fontweight='bold')
axs[0, 1].axis('off')  # Remove axes

axs[0, 2].text(0.5, 0.5, "Mask", fontsize=10, ha='center', va='center', fontweight='bold')
axs[0, 2].axis('off')  # Remove axes

axs[0, 3].text(0.5, 0.5, "MRI Image", fontsize=10, ha='center', va='center', fontweight='bold')
axs[0, 3].axis('off')  # Remove axes

axs[0, 4].text(0.5, 0.5, "Mask", fontsize=10, ha='center', va='center', fontweight='bold')
axs[0, 4].axis('off')  # Remove axes

for i, class_name in enumerate(classes):
    # Find an image and mask index for each class
    class_index = classes.index(class_name)
    
    # Retrieve an example image and mask for each class
    example_index1 = np.where(labels == class_index)[0][0]  # Take the first example of each class
    example_index2 = np.where(labels == class_index)[0][2]  # Take the second example 
    image1 = images[example_index1]
    mask1 = masks[example_index1]
    
    image2 = images[example_index2]
    mask2 = masks[example_index2]
    
    # Display the image
    axs[i + 1, 1].imshow(image1, cmap='gray')
    axs[i + 1, 1].axis('off')  # Remove axes

    # Display the mask
    axs[i + 1, 2].imshow(mask1, cmap='gray')
    axs[i + 1, 2].axis('off')  # Remove axes
    
    # Display the image
    axs[i + 1, 3].imshow(image2, cmap='gray')
    axs[i + 1, 3].axis('off')  # Remove axes

    # Display the mask
    axs[i + 1, 4].imshow(mask2, cmap='gray')
    axs[i + 1, 4].axis('off')  # Remove axes

    # Center the text in the class column
    axs[i + 1, 0].text(0.5, 0.5, class_name, fontsize=10, ha='center', va='center', fontweight='bold')
    axs[i + 1, 0].axis('off')  # Remove axes

plt.tight_layout()
plt.show()

# %%
# Split the data into training (75%) and validation (25%) sets
images_train, images_val, masks_train, masks_val, labels_train, labels_val = train_test_split(
    images, masks, labels, test_size=0.3, random_state=42, stratify=labels, shuffle=True
)

# Display the dimensions of the datasets
print(f"Training set - Images: {images_train.shape}, Masks: {masks_train.shape}, Labels: {labels_train.shape}")
print(f"Validation set - Images: {images_val.shape}, Masks: {masks_val.shape}, Labels: {labels_val.shape}")
# Out:
# Training set - Images: (2965, 128, 128, 1), Masks: (2965, 128, 128, 1), Labels: (2965,)
# Validation set - Images: (1272, 128, 128, 1), Masks: (1272, 128, 128, 1), Labels: (1272,)

# %%
# Function to create a generator that applies the same augmentation to images and masks
def train_generator(images, masks, batch_size, seed=42):
    image_datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        fill_mode='nearest'
    )
    
    mask_datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        fill_mode='nearest'
    )
    
    # Generators for images and masks
    image_generator = image_datagen.flow(images, batch_size=batch_size, seed=seed)
    mask_generator = mask_datagen.flow(masks, batch_size=batch_size, seed=seed)
    
    while True:
        # Generate a batch of images and masks
        img_batch = next(image_generator)  # Use `next(image_generator)`
        mask_batch = next(mask_generator)  # Use `next(mask_generator)`
        
        yield img_batch, mask_batch

# %%
# Function to display images and their corresponding masks
def plot_images(images, masks, num_images=5):
    plt.figure(figsize=(15, 6))
    for i in range(num_images):
        # Display the image
        plt.subplot(2, num_images, i + 1)
        plt.imshow(images[i].reshape(128, 128), cmap='gray')  # Adjust shape if needed
        plt.axis('off')
        plt.title('Image')

        # Display the corresponding mask
        plt.subplot(2, num_images, i + 1 + num_images)
        plt.imshow(masks[i].reshape(128, 128), cmap='gray')  # Adjust shape if needed
        plt.axis('off')
        plt.title('Mask')
    
    plt.tight_layout()
    plt.show()

# Test the augmentation generator by taking a few images
images_batch, masks_batch = next(train_generator(images_train, masks_train, batch_size=5))

# Display the images and masks
plot_images(images_batch, masks_batch, num_images=5)

# %%
# Dice Coefficient
def dice_coefficient(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Dice Loss (to be used as a loss function)
def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

# Hausdorff Loss
import tensorflow as tf

def compute_dtm(img, max_distance):
    """
    Computes the distance transform map for the binary image.
    
    Args:
        img (tf.Tensor): Binary image (batch, height, width, channels).
        max_distance (int): Maximum distance to clip the distance map.
        
    Returns:
        tf.Tensor: Distance transform map.
    """
    img = tf.cast(img, tf.float32)
    img = 1 - img  # Invert image so that distance is computed to zero pixels
    dt = tf.py_function(func=lambda x: tf.image.distance_transform_edt(x), inp=[img], Tout=tf.float32)
    dt = tf.clip_by_value(dt, 0, max_distance)
    return dt

def hausdorff_loss(y_true, y_pred, smooth=1):
    """
    Computes the Hausdorff distance loss between the predicted and ground truth masks.
    
    Args:
        y_true (tf.Tensor): Ground truth binary masks (batch, height, width, channels).
        y_pred (tf.Tensor): Predicted binary masks (batch, height, width, channels).
        smooth (float): Smoothing term to avoid division by zero.
        
    Returns:
        tf.Tensor: Hausdorff loss value.
    """
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Compute the distance transform maps
    dt_true = compute_dtm(y_true, max_distance=128)
    dt_pred = compute_dtm(y_pred, max_distance=128)

    # Calculate loss based on the distance `
    hd_loss_1 = tf.reduce_mean(y_pred * (dt_true ** 2))
    hd_loss_2 = tf.reduce_mean(y_true * (dt_pred ** 2))

    # Final Hausdorff loss
    hausdorff_loss_value = hd_loss_1 + hd_loss_2 + smooth
    return hausdorff_loss_value   

# Intersection over Union (IoU)
def iou(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    total = K.sum(y_true_f) + K.sum(y_pred_f)
    union = total - intersection
    return (intersection + smooth) / (union + smooth)

# %%
# Define the U-Net model
def unet_model(input_shape):
    inputs = layers.Input(input_shape)

    # Contracting Path (Encoder)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Dropout(0.1)(c1)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Dropout(0.1)(c2)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Dropout(0.2)(c3)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Dropout(0.2)(c4)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    # Bottleneck (bottom layer)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Dropout(0.3)(c5)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)

    # Expanding Path (Decoder)
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Dropout(0.2)(c6)
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Dropout(0.2)(c7)
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Dropout(0.1)(c8)
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Dropout(0.1)(c9)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c9)

    # Output layer with a single channel, for binary segmentation
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    # Create the model
    model = models.Model(inputs=[inputs], outputs=[outputs])
    
    return model


# Define the input shape (height, width, channels)
hausdorff_loss = 'binary_crossentropy'
input_shape = (128, 128, 1) 
model = unet_model(input_shape)
model.summary()

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4), loss=hausdorff_loss, metrics=['accuracy', dice_coefficient, iou])
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 128, 128,  │        640 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 128, 128,  │          0 │ conv2d_38[0][0]   │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 128, 128,  │     36,928 │ dropout_18[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 64, 64,    │          0 │ conv2d_39[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 64, 64,    │     73,856 │ max_pooling2d_8[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 64, 64,    │          0 │ conv2d_40[0][0]   │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 64, 64,    │    147,584 │ dropout_19[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 32, 32,    │          0 │ conv2d_41[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 32, 32,    │    295,168 │ max_pooling2d_9[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 32, 32,    │          0 │ conv2d_42[0][0]   │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 32, 32,    │    590,080 │ dropout_20[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 16, 16,    │          0 │ conv2d_43[0][0]   │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_10… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 16, 16,    │          0 │ conv2d_44[0][0]   │
# │ (Dropout)           │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ dropout_21[0][0]  │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 8, 8, 512) │          0 │ conv2d_45[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 8, 8,      │  4,719,616 │ max_pooling2d_11… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 8, 8,      │          0 │ conv2d_46[0][0]   │
# │ (Dropout)           │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 8, 8,      │  9,438,208 │ dropout_22[0][0]  │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 16, 16,    │  2,097,664 │ conv2d_47[0][0]   │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_45[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 16, 16,    │  4,719,104 │ concatenate_8[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 16, 16,    │          0 │ conv2d_48[0][0]   │
# │ (Dropout)           │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ dropout_23[0][0]  │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 32, 32,    │    524,544 │ conv2d_49[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_43[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_9[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 32, 32,    │          0 │ conv2d_50[0][0]   │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 32, 32,    │    590,080 │ dropout_24[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_10 │ (None, 64, 64,    │    131,200 │ conv2d_51[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_41[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_10[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 64, 64,    │          0 │ conv2d_52[0][0]   │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 64, 64,    │    147,584 │ dropout_25[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_11 │ (None, 128, 128,  │     32,832 │ conv2d_53[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_39[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_11[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 128, 128,  │          0 │ conv2d_54[0][0]   │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 128, 128,  │     36,928 │ dropout_26[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 128, 128,  │         65 │ conv2d_55[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,030,593 (118.37 MB)
#  Trainable params: 31,030,593 (118.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define the callbacks
model_checkpoint = ModelCheckpoint('best_unetmodel.keras',  # File name to save the best model
                                   monitor='val_dice_coefficient',  # Track the validation Dice Coefficient value
                                   save_best_only=True,  # Save only the best model
                                   mode='max',  # Look for the maximum value
                                   verbose=1  # Display a message when saving the model
                                  )

early_stopping = EarlyStopping(monitor='val_dice_coefficient',
                               patience=10,  # Stop after 10 epochs without improvement
                               mode='max',  # Look for the maximum value
                               verbose=1  # Display a message when stopping
                              )

# Use the augmentation generator for training
batch_size = 32
train_gen = train_generator(images_train, masks_train, batch_size=batch_size)

# Train the model with the generator
history = model.fit(
    train_gen,
    steps_per_epoch=len(images_train) // batch_size,
    epochs=100,
    validation_data=(images_val, masks_val),
    callbacks=[model_checkpoint, early_stopping]
)
# Out:
# Epoch 1/100
#  1/92 ━━━━━━━━━━━━━━━━━━━━ 58:16 38s/step - accuracy: 0.5626 - dice_coefficient: 0.0205 - iou: 0.0103 - loss: 0.6923
# I0000 00:00:1731948542.311296      97 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9600 - dice_coefficient: 0.0133 - iou: 0.0067 - loss: 0.3783
# Epoch 1: val_dice_coefficient improved from -inf to 0.04510, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 66s 301ms/step - accuracy: 0.9602 - dice_coefficient: 0.0134 - iou: 0.0068 - loss: 0.3763 - val_accuracy: 0.9874 - val_dice_coefficient: 0.0451 - val_iou: 0.0231 - val_loss: 0.0592
# Epoch 2/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9851 - dice_coefficient: 0.0342 - iou: 0.0175 - loss: 0.0479
# Epoch 2: val_dice_coefficient improved from 0.04510 to 0.05287, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 46s 221ms/step - accuracy: 0.9851 - dice_coefficient: 0.0342 - iou: 0.0175 - loss: 0.0479 - val_accuracy: 0.9874 - val_dice_coefficient: 0.0529 - val_iou: 0.0272 - val_loss: 0.0640
# Epoch 3/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9858 - dice_coefficient: 0.0406 - iou: 0.0208 - loss: 0.0439
# Epoch 3: val_dice_coefficient improved from 0.05287 to 0.06433, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9858 - dice_coefficient: 0.0406 - iou: 0.0208 - loss: 0.0439 - val_accuracy: 0.9874 - val_dice_coefficient: 0.0643 - val_iou: 0.0333 - val_loss: 0.0486
# Epoch 4/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9851 - dice_coefficient: 0.0458 - iou: 0.0235 - loss: 0.0457
# Epoch 4: val_dice_coefficient did not improve from 0.06433
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9851 - dice_coefficient: 0.0459 - iou: 0.0235 - loss: 0.0457 - val_accuracy: 0.9874 - val_dice_coefficient: 0.0636 - val_iou: 0.0329 - val_loss: 0.0660
# Epoch 5/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9854 - dice_coefficient: 0.0480 - iou: 0.0247 - loss: 0.0469
# Epoch 5: val_dice_coefficient improved from 0.06433 to 0.07271, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 221ms/step - accuracy: 0.9854 - dice_coefficient: 0.0481 - iou: 0.0247 - loss: 0.0469 - val_accuracy: 0.9874 - val_dice_coefficient: 0.0727 - val_iou: 0.0378 - val_loss: 0.0417
# Epoch 6/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9851 - dice_coefficient: 0.0649 - iou: 0.0337 - loss: 0.0425
# Epoch 6: val_dice_coefficient did not improve from 0.07271
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9851 - dice_coefficient: 0.0650 - iou: 0.0337 - loss: 0.0425 - val_accuracy: 0.9874 - val_dice_coefficient: 0.0704 - val_iou: 0.0366 - val_loss: 0.0406
# Epoch 7/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9851 - dice_coefficient: 0.0913 - iou: 0.0480 - loss: 0.0403
# Epoch 7: val_dice_coefficient improved from 0.07271 to 0.09386, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9851 - dice_coefficient: 0.0914 - iou: 0.0480 - loss: 0.0403 - val_accuracy: 0.9874 - val_dice_coefficient: 0.0939 - val_iou: 0.0494 - val_loss: 0.0375
# Epoch 8/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9850 - dice_coefficient: 0.1161 - iou: 0.0619 - loss: 0.0390
# Epoch 8: val_dice_coefficient improved from 0.09386 to 0.12769, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9850 - dice_coefficient: 0.1161 - iou: 0.0619 - loss: 0.0390 - val_accuracy: 0.9874 - val_dice_coefficient: 0.1277 - val_iou: 0.0684 - val_loss: 0.0371
# Epoch 9/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9854 - dice_coefficient: 0.1440 - iou: 0.0780 - loss: 0.0362
# Epoch 9: val_dice_coefficient improved from 0.12769 to 0.13210, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9854 - dice_coefficient: 0.1442 - iou: 0.0781 - loss: 0.0362 - val_accuracy: 0.9874 - val_dice_coefficient: 0.1321 - val_iou: 0.0711 - val_loss: 0.0359
# Epoch 10/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9855 - dice_coefficient: 0.2002 - iou: 0.1120 - loss: 0.0325
# Epoch 10: val_dice_coefficient improved from 0.13210 to 0.19132, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9855 - dice_coefficient: 0.2004 - iou: 0.1121 - loss: 0.0325 - val_accuracy: 0.9881 - val_dice_coefficient: 0.1913 - val_iou: 0.1064 - val_loss: 0.0307
# Epoch 11/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9865 - dice_coefficient: 0.2852 - iou: 0.1683 - loss: 0.0292
# Epoch 11: val_dice_coefficient improved from 0.19132 to 0.25992, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9865 - dice_coefficient: 0.2854 - iou: 0.1684 - loss: 0.0292 - val_accuracy: 0.9883 - val_dice_coefficient: 0.2599 - val_iou: 0.1512 - val_loss: 0.0315
# Epoch 12/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9868 - dice_coefficient: 0.3771 - iou: 0.2347 - loss: 0.0271
# Epoch 12: val_dice_coefficient improved from 0.25992 to 0.48732, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9868 - dice_coefficient: 0.3772 - iou: 0.2347 - loss: 0.0271 - val_accuracy: 0.9904 - val_dice_coefficient: 0.4873 - val_iou: 0.3251 - val_loss: 0.0217
# Epoch 13/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9880 - dice_coefficient: 0.4639 - iou: 0.3046 - loss: 0.0231
# Epoch 13: val_dice_coefficient improved from 0.48732 to 0.49998, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9880 - dice_coefficient: 0.4638 - iou: 0.3045 - loss: 0.0231 - val_accuracy: 0.9911 - val_dice_coefficient: 0.5000 - val_iou: 0.3363 - val_loss: 0.0202
# Epoch 14/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9878 - dice_coefficient: 0.4592 - iou: 0.3014 - loss: 0.0230
# Epoch 14: val_dice_coefficient did not improve from 0.49998
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9878 - dice_coefficient: 0.4595 - iou: 0.3016 - loss: 0.0230 - val_accuracy: 0.9916 - val_dice_coefficient: 0.4686 - val_iou: 0.3082 - val_loss: 0.0196
# Epoch 15/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9885 - dice_coefficient: 0.4924 - iou: 0.3308 - loss: 0.0211
# Epoch 15: val_dice_coefficient improved from 0.49998 to 0.56670, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9885 - dice_coefficient: 0.4926 - iou: 0.3309 - loss: 0.0211 - val_accuracy: 0.9918 - val_dice_coefficient: 0.5667 - val_iou: 0.3989 - val_loss: 0.0172
# Epoch 16/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9892 - dice_coefficient: 0.5969 - iou: 0.4294 - loss: 0.0165
# Epoch 16: val_dice_coefficient did not improve from 0.56670
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9892 - dice_coefficient: 0.5966 - iou: 0.4291 - loss: 0.0165 - val_accuracy: 0.9896 - val_dice_coefficient: 0.5276 - val_iou: 0.3614 - val_loss: 0.0211
# Epoch 17/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9884 - dice_coefficient: 0.5380 - iou: 0.3731 - loss: 0.0196
# Epoch 17: val_dice_coefficient improved from 0.56670 to 0.61059, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9884 - dice_coefficient: 0.5383 - iou: 0.3734 - loss: 0.0196 - val_accuracy: 0.9919 - val_dice_coefficient: 0.6106 - val_iou: 0.4420 - val_loss: 0.0151
# Epoch 18/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9890 - dice_coefficient: 0.5877 - iou: 0.4191 - loss: 0.0177
# Epoch 18: val_dice_coefficient improved from 0.61059 to 0.64276, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9890 - dice_coefficient: 0.5880 - iou: 0.4193 - loss: 0.0177 - val_accuracy: 0.9924 - val_dice_coefficient: 0.6428 - val_iou: 0.4766 - val_loss: 0.0140
# Epoch 19/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9895 - dice_coefficient: 0.6340 - iou: 0.4677 - loss: 0.0151
# Epoch 19: val_dice_coefficient did not improve from 0.64276
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9895 - dice_coefficient: 0.6339 - iou: 0.4677 - loss: 0.0151 - val_accuracy: 0.9919 - val_dice_coefficient: 0.6115 - val_iou: 0.4431 - val_loss: 0.0146
# Epoch 20/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9893 - dice_coefficient: 0.6480 - iou: 0.4823 - loss: 0.0143
# Epoch 20: val_dice_coefficient improved from 0.64276 to 0.70532, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9893 - dice_coefficient: 0.6482 - iou: 0.4824 - loss: 0.0143 - val_accuracy: 0.9929 - val_dice_coefficient: 0.7053 - val_iou: 0.5478 - val_loss: 0.0121
# Epoch 21/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9898 - dice_coefficient: 0.6887 - iou: 0.5284 - loss: 0.0127
# Epoch 21: val_dice_coefficient improved from 0.70532 to 0.70611, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9898 - dice_coefficient: 0.6886 - iou: 0.5283 - loss: 0.0127 - val_accuracy: 0.9929 - val_dice_coefficient: 0.7061 - val_iou: 0.5490 - val_loss: 0.0114
# Epoch 22/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9904 - dice_coefficient: 0.6792 - iou: 0.5181 - loss: 0.0126
# Epoch 22: val_dice_coefficient did not improve from 0.70611
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9904 - dice_coefficient: 0.6790 - iou: 0.5179 - loss: 0.0126 - val_accuracy: 0.9930 - val_dice_coefficient: 0.6579 - val_iou: 0.4929 - val_loss: 0.0113
# Epoch 23/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9903 - dice_coefficient: 0.6904 - iou: 0.5333 - loss: 0.0117
# Epoch 23: val_dice_coefficient improved from 0.70611 to 0.72161, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9903 - dice_coefficient: 0.6906 - iou: 0.5335 - loss: 0.0117 - val_accuracy: 0.9932 - val_dice_coefficient: 0.7216 - val_iou: 0.5669 - val_loss: 0.0104
# Epoch 24/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9900 - dice_coefficient: 0.7120 - iou: 0.5561 - loss: 0.0114
# Epoch 24: val_dice_coefficient improved from 0.72161 to 0.73037, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9900 - dice_coefficient: 0.7120 - iou: 0.5560 - loss: 0.0114 - val_accuracy: 0.9931 - val_dice_coefficient: 0.7304 - val_iou: 0.5777 - val_loss: 0.0104
# Epoch 25/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9903 - dice_coefficient: 0.7263 - iou: 0.5744 - loss: 0.0105
# Epoch 25: val_dice_coefficient improved from 0.73037 to 0.73838, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 219ms/step - accuracy: 0.9903 - dice_coefficient: 0.7264 - iou: 0.5744 - loss: 0.0105 - val_accuracy: 0.9934 - val_dice_coefficient: 0.7384 - val_iou: 0.5880 - val_loss: 0.0102
# Epoch 26/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9901 - dice_coefficient: 0.7098 - iou: 0.5533 - loss: 0.0114
# Epoch 26: val_dice_coefficient improved from 0.73838 to 0.75505, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9901 - dice_coefficient: 0.7099 - iou: 0.5534 - loss: 0.0114 - val_accuracy: 0.9935 - val_dice_coefficient: 0.7550 - val_iou: 0.6083 - val_loss: 0.0090
# Epoch 27/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9908 - dice_coefficient: 0.7472 - iou: 0.5987 - loss: 0.0097
# Epoch 27: val_dice_coefficient improved from 0.75505 to 0.76320, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9908 - dice_coefficient: 0.7471 - iou: 0.5987 - loss: 0.0097 - val_accuracy: 0.9936 - val_dice_coefficient: 0.7632 - val_iou: 0.6193 - val_loss: 0.0090
# Epoch 28/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9907 - dice_coefficient: 0.7411 - iou: 0.5923 - loss: 0.0094
# Epoch 28: val_dice_coefficient improved from 0.76320 to 0.76790, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9907 - dice_coefficient: 0.7412 - iou: 0.5924 - loss: 0.0094 - val_accuracy: 0.9936 - val_dice_coefficient: 0.7679 - val_iou: 0.6252 - val_loss: 0.0084
# Epoch 29/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9908 - dice_coefficient: 0.7658 - iou: 0.6224 - loss: 0.0089
# Epoch 29: val_dice_coefficient improved from 0.76790 to 0.77169, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9908 - dice_coefficient: 0.7657 - iou: 0.6224 - loss: 0.0089 - val_accuracy: 0.9937 - val_dice_coefficient: 0.7717 - val_iou: 0.6302 - val_loss: 0.0082
# Epoch 30/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9904 - dice_coefficient: 0.7542 - iou: 0.6090 - loss: 0.0091
# Epoch 30: val_dice_coefficient improved from 0.77169 to 0.78427, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9904 - dice_coefficient: 0.7544 - iou: 0.6091 - loss: 0.0091 - val_accuracy: 0.9937 - val_dice_coefficient: 0.7843 - val_iou: 0.6468 - val_loss: 0.0078
# Epoch 31/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9908 - dice_coefficient: 0.7605 - iou: 0.6165 - loss: 0.0091
# Epoch 31: val_dice_coefficient did not improve from 0.78427
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9908 - dice_coefficient: 0.7605 - iou: 0.6165 - loss: 0.0091 - val_accuracy: 0.9936 - val_dice_coefficient: 0.7674 - val_iou: 0.6245 - val_loss: 0.0084
# Epoch 32/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9906 - dice_coefficient: 0.7641 - iou: 0.6207 - loss: 0.0092
# Epoch 32: val_dice_coefficient improved from 0.78427 to 0.80254, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9906 - dice_coefficient: 0.7641 - iou: 0.6207 - loss: 0.0092 - val_accuracy: 0.9939 - val_dice_coefficient: 0.8025 - val_iou: 0.6720 - val_loss: 0.0077
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9909 - dice_coefficient: 0.7930 - iou: 0.6588 - loss: 0.0076
# Epoch 33: val_dice_coefficient did not improve from 0.80254
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 204ms/step - accuracy: 0.9909 - dice_coefficient: 0.7929 - iou: 0.6587 - loss: 0.0076 - val_accuracy: 0.9933 - val_dice_coefficient: 0.7588 - val_iou: 0.6130 - val_loss: 0.0090
# Epoch 34/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9903 - dice_coefficient: 0.7568 - iou: 0.6127 - loss: 0.0097
# Epoch 34: val_dice_coefficient improved from 0.80254 to 0.80385, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 219ms/step - accuracy: 0.9903 - dice_coefficient: 0.7570 - iou: 0.6129 - loss: 0.0096 - val_accuracy: 0.9940 - val_dice_coefficient: 0.8039 - val_iou: 0.6734 - val_loss: 0.0072
# Epoch 35/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9912 - dice_coefficient: 0.7998 - iou: 0.6682 - loss: 0.0072
# Epoch 35: val_dice_coefficient improved from 0.80385 to 0.81038, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9912 - dice_coefficient: 0.7998 - iou: 0.6683 - loss: 0.0072 - val_accuracy: 0.9940 - val_dice_coefficient: 0.8104 - val_iou: 0.6829 - val_loss: 0.0079
# Epoch 36/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9912 - dice_coefficient: 0.7997 - iou: 0.6676 - loss: 0.0072
# Epoch 36: val_dice_coefficient did not improve from 0.81038
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9912 - dice_coefficient: 0.7997 - iou: 0.6676 - loss: 0.0072 - val_accuracy: 0.9938 - val_dice_coefficient: 0.7942 - val_iou: 0.6604 - val_loss: 0.0074
# Epoch 37/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9909 - dice_coefficient: 0.8041 - iou: 0.6745 - loss: 0.0073
# Epoch 37: val_dice_coefficient improved from 0.81038 to 0.81331, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9909 - dice_coefficient: 0.8040 - iou: 0.6745 - loss: 0.0073 - val_accuracy: 0.9940 - val_dice_coefficient: 0.8133 - val_iou: 0.6867 - val_loss: 0.0080
# Epoch 38/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9914 - dice_coefficient: 0.8001 - iou: 0.6685 - loss: 0.0070
# Epoch 38: val_dice_coefficient did not improve from 0.81331
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9914 - dice_coefficient: 0.8001 - iou: 0.6686 - loss: 0.0070 - val_accuracy: 0.9940 - val_dice_coefficient: 0.8130 - val_iou: 0.6861 - val_loss: 0.0075
# Epoch 39/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9909 - dice_coefficient: 0.7994 - iou: 0.6682 - loss: 0.0076
# Epoch 39: val_dice_coefficient improved from 0.81331 to 0.82064, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9909 - dice_coefficient: 0.7994 - iou: 0.6682 - loss: 0.0076 - val_accuracy: 0.9940 - val_dice_coefficient: 0.8206 - val_iou: 0.6973 - val_loss: 0.0074
# Epoch 40/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9915 - dice_coefficient: 0.8192 - iou: 0.6948 - loss: 0.0063
# Epoch 40: val_dice_coefficient did not improve from 0.82064
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9915 - dice_coefficient: 0.8192 - iou: 0.6947 - loss: 0.0063 - val_accuracy: 0.9942 - val_dice_coefficient: 0.8057 - val_iou: 0.6763 - val_loss: 0.0068
# Epoch 41/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9908 - dice_coefficient: 0.8142 - iou: 0.6878 - loss: 0.0069
# Epoch 41: val_dice_coefficient did not improve from 0.82064
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9908 - dice_coefficient: 0.8142 - iou: 0.6878 - loss: 0.0069 - val_accuracy: 0.9941 - val_dice_coefficient: 0.8023 - val_iou: 0.6720 - val_loss: 0.0074
# Epoch 42/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9913 - dice_coefficient: 0.8145 - iou: 0.6884 - loss: 0.0066
# Epoch 42: val_dice_coefficient improved from 0.82064 to 0.82090, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9913 - dice_coefficient: 0.8145 - iou: 0.6884 - loss: 0.0066 - val_accuracy: 0.9941 - val_dice_coefficient: 0.8209 - val_iou: 0.6981 - val_loss: 0.0073
# Epoch 43/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9908 - dice_coefficient: 0.8112 - iou: 0.6839 - loss: 0.0072
# Epoch 43: val_dice_coefficient did not improve from 0.82090
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9908 - dice_coefficient: 0.8112 - iou: 0.6839 - loss: 0.0072 - val_accuracy: 0.9940 - val_dice_coefficient: 0.8037 - val_iou: 0.6736 - val_loss: 0.0078
# Epoch 44/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9908 - dice_coefficient: 0.7821 - iou: 0.6447 - loss: 0.0082
# Epoch 44: val_dice_coefficient did not improve from 0.82090
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9908 - dice_coefficient: 0.7821 - iou: 0.6448 - loss: 0.0082 - val_accuracy: 0.9940 - val_dice_coefficient: 0.8148 - val_iou: 0.6893 - val_loss: 0.0078
# Epoch 45/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9911 - dice_coefficient: 0.8060 - iou: 0.6775 - loss: 0.0070
# Epoch 45: val_dice_coefficient did not improve from 0.82090
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9911 - dice_coefficient: 0.8059 - iou: 0.6774 - loss: 0.0070 - val_accuracy: 0.9940 - val_dice_coefficient: 0.7987 - val_iou: 0.6671 - val_loss: 0.0077
# Epoch 46/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9909 - dice_coefficient: 0.8241 - iou: 0.7019 - loss: 0.0066
# Epoch 46: val_dice_coefficient did not improve from 0.82090
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9909 - dice_coefficient: 0.8240 - iou: 0.7019 - loss: 0.0066 - val_accuracy: 0.9940 - val_dice_coefficient: 0.8101 - val_iou: 0.6827 - val_loss: 0.0075
# Epoch 47/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9913 - dice_coefficient: 0.7974 - iou: 0.6661 - loss: 0.0070
# Epoch 47: val_dice_coefficient improved from 0.82090 to 0.83437, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9913 - dice_coefficient: 0.7975 - iou: 0.6662 - loss: 0.0070 - val_accuracy: 0.9942 - val_dice_coefficient: 0.8344 - val_iou: 0.7174 - val_loss: 0.0070
# Epoch 48/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9912 - dice_coefficient: 0.8260 - iou: 0.7046 - loss: 0.0062
# Epoch 48: val_dice_coefficient did not improve from 0.83437
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9912 - dice_coefficient: 0.8260 - iou: 0.7046 - loss: 0.0062 - val_accuracy: 0.9943 - val_dice_coefficient: 0.8309 - val_iou: 0.7121 - val_loss: 0.0062
# Epoch 49/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9914 - dice_coefficient: 0.8241 - iou: 0.7024 - loss: 0.0060
# Epoch 49: val_dice_coefficient improved from 0.83437 to 0.83992, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9914 - dice_coefficient: 0.8242 - iou: 0.7025 - loss: 0.0060 - val_accuracy: 0.9943 - val_dice_coefficient: 0.8399 - val_iou: 0.7254 - val_loss: 0.0065
# Epoch 50/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9913 - dice_coefficient: 0.8335 - iou: 0.7162 - loss: 0.0059
# Epoch 50: val_dice_coefficient did not improve from 0.83992
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9913 - dice_coefficient: 0.8335 - iou: 0.7162 - loss: 0.0059 - val_accuracy: 0.9943 - val_dice_coefficient: 0.8270 - val_iou: 0.7064 - val_loss: 0.0063
# Epoch 51/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9915 - dice_coefficient: 0.8245 - iou: 0.7028 - loss: 0.0060
# Epoch 51: val_dice_coefficient did not improve from 0.83992
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9915 - dice_coefficient: 0.8245 - iou: 0.7029 - loss: 0.0060 - val_accuracy: 0.9942 - val_dice_coefficient: 0.8311 - val_iou: 0.7123 - val_loss: 0.0066
# Epoch 52/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9914 - dice_coefficient: 0.8350 - iou: 0.7176 - loss: 0.0058
# Epoch 52: val_dice_coefficient improved from 0.83992 to 0.84206, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9914 - dice_coefficient: 0.8350 - iou: 0.7176 - loss: 0.0058 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8421 - val_iou: 0.7285 - val_loss: 0.0057
# Epoch 53/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9912 - dice_coefficient: 0.8440 - iou: 0.7309 - loss: 0.0056
# Epoch 53: val_dice_coefficient improved from 0.84206 to 0.85145, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9912 - dice_coefficient: 0.8440 - iou: 0.7309 - loss: 0.0056 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8515 - val_iou: 0.7424 - val_loss: 0.0059
# Epoch 54/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9917 - dice_coefficient: 0.8502 - iou: 0.7404 - loss: 0.0050
# Epoch 54: val_dice_coefficient improved from 0.85145 to 0.85469, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9917 - dice_coefficient: 0.8503 - iou: 0.7404 - loss: 0.0050 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8547 - val_iou: 0.7474 - val_loss: 0.0059
# Epoch 55/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9918 - dice_coefficient: 0.8433 - iou: 0.7298 - loss: 0.0052
# Epoch 55: val_dice_coefficient did not improve from 0.85469
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9918 - dice_coefficient: 0.8433 - iou: 0.7299 - loss: 0.0052 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8544 - val_iou: 0.7468 - val_loss: 0.0058
# Epoch 56/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9911 - dice_coefficient: 0.8526 - iou: 0.7438 - loss: 0.0054
# Epoch 56: val_dice_coefficient did not improve from 0.85469
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9911 - dice_coefficient: 0.8525 - iou: 0.7438 - loss: 0.0054 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8457 - val_iou: 0.7343 - val_loss: 0.0063
# Epoch 57/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9914 - dice_coefficient: 0.8581 - iou: 0.7521 - loss: 0.0050
# Epoch 57: val_dice_coefficient did not improve from 0.85469
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9914 - dice_coefficient: 0.8581 - iou: 0.7520 - loss: 0.0050 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8524 - val_iou: 0.7440 - val_loss: 0.0058
# Epoch 58/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9915 - dice_coefficient: 0.8593 - iou: 0.7540 - loss: 0.0049
# Epoch 58: val_dice_coefficient did not improve from 0.85469
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9915 - dice_coefficient: 0.8593 - iou: 0.7540 - loss: 0.0049 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8513 - val_iou: 0.7422 - val_loss: 0.0066
# Epoch 59/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9914 - dice_coefficient: 0.8016 - iou: 0.6739 - loss: 0.0071
# Epoch 59: val_dice_coefficient did not improve from 0.85469
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9914 - dice_coefficient: 0.8015 - iou: 0.6737 - loss: 0.0071 - val_accuracy: 0.9942 - val_dice_coefficient: 0.8206 - val_iou: 0.6971 - val_loss: 0.0063
# Epoch 60/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8349 - iou: 0.7175 - loss: 0.0056
# Epoch 60: val_dice_coefficient did not improve from 0.85469
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9916 - dice_coefficient: 0.8350 - iou: 0.7177 - loss: 0.0056 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8449 - val_iou: 0.7328 - val_loss: 0.0060
# Epoch 61/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9917 - dice_coefficient: 0.8558 - iou: 0.7488 - loss: 0.0050
# Epoch 61: val_dice_coefficient did not improve from 0.85469
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9917 - dice_coefficient: 0.8558 - iou: 0.7488 - loss: 0.0050 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8542 - val_iou: 0.7467 - val_loss: 0.0060
# Epoch 62/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9915 - dice_coefficient: 0.8632 - iou: 0.7601 - loss: 0.0048
# Epoch 62: val_dice_coefficient did not improve from 0.85469
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9915 - dice_coefficient: 0.8632 - iou: 0.7600 - loss: 0.0048 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8516 - val_iou: 0.7428 - val_loss: 0.0062
# Epoch 63/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9910 - dice_coefficient: 0.8614 - iou: 0.7571 - loss: 0.0052
# Epoch 63: val_dice_coefficient improved from 0.85469 to 0.85846, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9911 - dice_coefficient: 0.8614 - iou: 0.7571 - loss: 0.0052 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8585 - val_iou: 0.7531 - val_loss: 0.0056
# Epoch 64/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9915 - dice_coefficient: 0.8548 - iou: 0.7477 - loss: 0.0052
# Epoch 64: val_dice_coefficient did not improve from 0.85846
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9915 - dice_coefficient: 0.8547 - iou: 0.7475 - loss: 0.0052 - val_accuracy: 0.9943 - val_dice_coefficient: 0.8455 - val_iou: 0.7334 - val_loss: 0.0069
# Epoch 65/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9914 - dice_coefficient: 0.8375 - iou: 0.7219 - loss: 0.0060
# Epoch 65: val_dice_coefficient did not improve from 0.85846
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9914 - dice_coefficient: 0.8375 - iou: 0.7219 - loss: 0.0060 - val_accuracy: 0.9943 - val_dice_coefficient: 0.8415 - val_iou: 0.7277 - val_loss: 0.0060
# Epoch 66/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9915 - dice_coefficient: 0.8561 - iou: 0.7491 - loss: 0.0051
# Epoch 66: val_dice_coefficient did not improve from 0.85846
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9915 - dice_coefficient: 0.8561 - iou: 0.7491 - loss: 0.0051 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8479 - val_iou: 0.7370 - val_loss: 0.0058
# Epoch 67/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9915 - dice_coefficient: 0.8586 - iou: 0.7531 - loss: 0.0049
# Epoch 67: val_dice_coefficient did not improve from 0.85846
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9915 - dice_coefficient: 0.8586 - iou: 0.7531 - loss: 0.0049 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8572 - val_iou: 0.7510 - val_loss: 0.0058
# Epoch 68/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9915 - dice_coefficient: 0.8551 - iou: 0.7480 - loss: 0.0051
# Epoch 68: val_dice_coefficient did not improve from 0.85846
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9915 - dice_coefficient: 0.8551 - iou: 0.7480 - loss: 0.0051 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8570 - val_iou: 0.7510 - val_loss: 0.0058
# Epoch 69/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8658 - iou: 0.7639 - loss: 0.0047
# Epoch 69: val_dice_coefficient did not improve from 0.85846
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9916 - dice_coefficient: 0.8658 - iou: 0.7639 - loss: 0.0047 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8582 - val_iou: 0.7527 - val_loss: 0.0056
# Epoch 70/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9917 - dice_coefficient: 0.8693 - iou: 0.7694 - loss: 0.0045
# Epoch 70: val_dice_coefficient improved from 0.85846 to 0.86378, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9917 - dice_coefficient: 0.8693 - iou: 0.7694 - loss: 0.0045 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8638 - val_iou: 0.7613 - val_loss: 0.0053
# Epoch 71/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9914 - dice_coefficient: 0.8714 - iou: 0.7727 - loss: 0.0046
# Epoch 71: val_dice_coefficient did not improve from 0.86378
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9914 - dice_coefficient: 0.8713 - iou: 0.7727 - loss: 0.0046 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8460 - val_iou: 0.7347 - val_loss: 0.0061
# Epoch 72/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9917 - dice_coefficient: 0.8623 - iou: 0.7585 - loss: 0.0047
# Epoch 72: val_dice_coefficient did not improve from 0.86378
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9917 - dice_coefficient: 0.8623 - iou: 0.7585 - loss: 0.0047 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8534 - val_iou: 0.7457 - val_loss: 0.0068
# Epoch 73/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9919 - dice_coefficient: 0.8686 - iou: 0.7684 - loss: 0.0043
# Epoch 73: val_dice_coefficient improved from 0.86378 to 0.86560, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9919 - dice_coefficient: 0.8686 - iou: 0.7684 - loss: 0.0043 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8656 - val_iou: 0.7640 - val_loss: 0.0055
# Epoch 74/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8428 - iou: 0.7305 - loss: 0.0055
# Epoch 74: val_dice_coefficient did not improve from 0.86560
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9916 - dice_coefficient: 0.8425 - iou: 0.7301 - loss: 0.0055 - val_accuracy: 0.9938 - val_dice_coefficient: 0.7383 - val_iou: 0.5868 - val_loss: 0.0084
# Epoch 75/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9913 - dice_coefficient: 0.8313 - iou: 0.7131 - loss: 0.0059
# Epoch 75: val_dice_coefficient did not improve from 0.86560
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9913 - dice_coefficient: 0.8315 - iou: 0.7133 - loss: 0.0059 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8560 - val_iou: 0.7492 - val_loss: 0.0056
# Epoch 76/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9916 - dice_coefficient: 0.8551 - iou: 0.7479 - loss: 0.0050
# Epoch 76: val_dice_coefficient improved from 0.86560 to 0.86621, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 221ms/step - accuracy: 0.9916 - dice_coefficient: 0.8552 - iou: 0.7480 - loss: 0.0050 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8662 - val_iou: 0.7652 - val_loss: 0.0054
# Epoch 77/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8650 - iou: 0.7628 - loss: 0.0046
# Epoch 77: val_dice_coefficient did not improve from 0.86621
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9916 - dice_coefficient: 0.8651 - iou: 0.7628 - loss: 0.0046 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8622 - val_iou: 0.7586 - val_loss: 0.0053
# Epoch 78/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9917 - dice_coefficient: 0.8743 - iou: 0.7772 - loss: 0.0043
# Epoch 78: val_dice_coefficient did not improve from 0.86621
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9917 - dice_coefficient: 0.8743 - iou: 0.7771 - loss: 0.0043 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8477 - val_iou: 0.7368 - val_loss: 0.0058
# Epoch 79/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9917 - dice_coefficient: 0.8649 - iou: 0.7628 - loss: 0.0045
# Epoch 79: val_dice_coefficient did not improve from 0.86621
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9917 - dice_coefficient: 0.8649 - iou: 0.7629 - loss: 0.0045 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8629 - val_iou: 0.7600 - val_loss: 0.0059
# Epoch 80/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9919 - dice_coefficient: 0.8733 - iou: 0.7754 - loss: 0.0042
# Epoch 80: val_dice_coefficient did not improve from 0.86621
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9919 - dice_coefficient: 0.8733 - iou: 0.7755 - loss: 0.0042 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8649 - val_iou: 0.7632 - val_loss: 0.0055
# Epoch 81/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9914 - dice_coefficient: 0.8752 - iou: 0.7788 - loss: 0.0044
# Epoch 81: val_dice_coefficient improved from 0.86621 to 0.86650, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9914 - dice_coefficient: 0.8752 - iou: 0.7788 - loss: 0.0044 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8665 - val_iou: 0.7654 - val_loss: 0.0057
# Epoch 82/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8768 - iou: 0.7812 - loss: 0.0043
# Epoch 82: val_dice_coefficient did not improve from 0.86650
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9916 - dice_coefficient: 0.8768 - iou: 0.7812 - loss: 0.0043 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8653 - val_iou: 0.7636 - val_loss: 0.0057
# Epoch 83/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8746 - iou: 0.7777 - loss: 0.0045
# Epoch 83: val_dice_coefficient did not improve from 0.86650
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9916 - dice_coefficient: 0.8745 - iou: 0.7775 - loss: 0.0045 - val_accuracy: 0.9943 - val_dice_coefficient: 0.8370 - val_iou: 0.7208 - val_loss: 0.0061
# Epoch 84/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9909 - dice_coefficient: 0.8109 - iou: 0.6844 - loss: 0.0076
# Epoch 84: val_dice_coefficient did not improve from 0.86650
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9909 - dice_coefficient: 0.8108 - iou: 0.6843 - loss: 0.0076 - val_accuracy: 0.9942 - val_dice_coefficient: 0.8337 - val_iou: 0.7161 - val_loss: 0.0077
# Epoch 85/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9913 - dice_coefficient: 0.8427 - iou: 0.7298 - loss: 0.0059
# Epoch 85: val_dice_coefficient did not improve from 0.86650
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9913 - dice_coefficient: 0.8427 - iou: 0.7298 - loss: 0.0059 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8554 - val_iou: 0.7488 - val_loss: 0.0058
# Epoch 86/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8623 - iou: 0.7586 - loss: 0.0049
# Epoch 86: val_dice_coefficient did not improve from 0.86650
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9916 - dice_coefficient: 0.8624 - iou: 0.7586 - loss: 0.0049 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8611 - val_iou: 0.7576 - val_loss: 0.0059
# Epoch 87/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9918 - dice_coefficient: 0.8718 - iou: 0.7735 - loss: 0.0044
# Epoch 87: val_dice_coefficient improved from 0.86650 to 0.87065, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9918 - dice_coefficient: 0.8718 - iou: 0.7734 - loss: 0.0044 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8706 - val_iou: 0.7719 - val_loss: 0.0054
# Epoch 88/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9917 - dice_coefficient: 0.8721 - iou: 0.7739 - loss: 0.0043
# Epoch 88: val_dice_coefficient did not improve from 0.87065
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9917 - dice_coefficient: 0.8721 - iou: 0.7738 - loss: 0.0043 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8598 - val_iou: 0.7552 - val_loss: 0.0058
# Epoch 89/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9919 - dice_coefficient: 0.8713 - iou: 0.7726 - loss: 0.0044
# Epoch 89: val_dice_coefficient did not improve from 0.87065
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9919 - dice_coefficient: 0.8713 - iou: 0.7726 - loss: 0.0044 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8648 - val_iou: 0.7628 - val_loss: 0.0053
# Epoch 90/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9918 - dice_coefficient: 0.8763 - iou: 0.7804 - loss: 0.0043
# Epoch 90: val_dice_coefficient did not improve from 0.87065
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9918 - dice_coefficient: 0.8763 - iou: 0.7803 - loss: 0.0043 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8618 - val_iou: 0.7583 - val_loss: 0.0059
# Epoch 91/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9919 - dice_coefficient: 0.8712 - iou: 0.7725 - loss: 0.0043
# Epoch 91: val_dice_coefficient did not improve from 0.87065
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9919 - dice_coefficient: 0.8711 - iou: 0.7723 - loss: 0.0043 - val_accuracy: 0.9944 - val_dice_coefficient: 0.8634 - val_iou: 0.7607 - val_loss: 0.0056
# Epoch 92/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9917 - dice_coefficient: 0.8640 - iou: 0.7614 - loss: 0.0046
# Epoch 92: val_dice_coefficient did not improve from 0.87065
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9917 - dice_coefficient: 0.8641 - iou: 0.7615 - loss: 0.0046 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8632 - val_iou: 0.7607 - val_loss: 0.0054
# Epoch 93/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9918 - dice_coefficient: 0.8794 - iou: 0.7852 - loss: 0.0041
# Epoch 93: val_dice_coefficient did not improve from 0.87065
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9918 - dice_coefficient: 0.8794 - iou: 0.7852 - loss: 0.0041 - val_accuracy: 0.9945 - val_dice_coefficient: 0.8609 - val_iou: 0.7569 - val_loss: 0.0056
# Epoch 94/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9917 - dice_coefficient: 0.8782 - iou: 0.7833 - loss: 0.0041
# Epoch 94: val_dice_coefficient improved from 0.87065 to 0.87296, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9917 - dice_coefficient: 0.8782 - iou: 0.7833 - loss: 0.0041 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8730 - val_iou: 0.7754 - val_loss: 0.0050
# Epoch 95/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9919 - dice_coefficient: 0.8817 - iou: 0.7888 - loss: 0.0039
# Epoch 95: val_dice_coefficient did not improve from 0.87296
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 204ms/step - accuracy: 0.9919 - dice_coefficient: 0.8817 - iou: 0.7888 - loss: 0.0039 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8689 - val_iou: 0.7690 - val_loss: 0.0052
# Epoch 96/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8827 - iou: 0.7904 - loss: 0.0041
# Epoch 96: val_dice_coefficient improved from 0.87296 to 0.87773, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9916 - dice_coefficient: 0.8827 - iou: 0.7904 - loss: 0.0041 - val_accuracy: 0.9947 - val_dice_coefficient: 0.8777 - val_iou: 0.7829 - val_loss: 0.0048
# Epoch 97/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9917 - dice_coefficient: 0.8825 - iou: 0.7901 - loss: 0.0040
# Epoch 97: val_dice_coefficient did not improve from 0.87773
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9917 - dice_coefficient: 0.8825 - iou: 0.7901 - loss: 0.0040 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8755 - val_iou: 0.7797 - val_loss: 0.0053
# Epoch 98/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8873 - iou: 0.7978 - loss: 0.0039
# Epoch 98: val_dice_coefficient did not improve from 0.87773
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9916 - dice_coefficient: 0.8873 - iou: 0.7978 - loss: 0.0039 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8736 - val_iou: 0.7766 - val_loss: 0.0054
# Epoch 99/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9916 - dice_coefficient: 0.8885 - iou: 0.7997 - loss: 0.0039
# Epoch 99: val_dice_coefficient did not improve from 0.87773
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.9916 - dice_coefficient: 0.8885 - iou: 0.7996 - loss: 0.0039 - val_accuracy: 0.9946 - val_dice_coefficient: 0.8722 - val_iou: 0.7743 - val_loss: 0.0053
# Epoch 100/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9921 - dice_coefficient: 0.8817 - iou: 0.7887 - loss: 0.0037
# Epoch 100: val_dice_coefficient improved from 0.87773 to 0.88066, saving model to best_unetmodel.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9921 - dice_coefficient: 0.8817 - iou: 0.7888 - loss: 0.0037 - val_accuracy: 0.9947 - val_dice_coefficient: 0.8807 - val_iou: 0.7877 - val_loss: 0.0053

# %%
# Evaluate the model on the training set
train_loss, train_accuracy, train_dice_coef, train_iou_coef = model.evaluate(images_train, masks_train, verbose=1)
print(f'Training Loss: {train_loss:.4f}')
print(f'Training Accuracy: {train_accuracy:.4f}')
print(f'Training Dice Coefficient: {train_dice_coef:.4f}')
print(f'Training IoU Coefficient: {train_iou_coef:.4f}')
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9949 - dice_coefficient: 0.9041 - iou: 0.8254 - loss: 0.0032
# Training Loss: 0.0030
# Training Accuracy: 0.9951
# Training Dice Coefficient: 0.9054
# Training IoU Coefficient: 0.8275

# %%
# Evaluate the model on the validation set
val_loss, val_accuracy, val_dice_coef, val_iou_coef = model.evaluate(images_val, masks_val, verbose=1)
print(f'Validation Loss: {val_loss:.4f}')
print(f'Validation Accuracy: {val_accuracy:.4f}')
print(f'Validation Dice Coefficient: {val_dice_coef:.4f}')
print(f'Validation IoU Coefficient: {val_iou_coef:.4f}')
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9947 - dice_coefficient: 0.8791 - iou: 0.7854 - loss: 0.0053
# Validation Loss: 0.0053
# Validation Accuracy: 0.9947
# Validation Dice Coefficient: 0.8807
# Validation IoU Coefficient: 0.7877

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Plot the Loss curve
axs[0, 0].plot(history.history['loss'], label='Training Loss')
axs[0, 0].plot(history.history['val_loss'], label='Validation Loss')
axs[0, 0].set_title('Loss over Epochs')
axs[0, 0].set_xlabel('Epochs')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].set_ylim(0, 1)
axs[0, 0].legend()

# Plot the Accuracy curve
axs[0, 1].plot(history.history['accuracy'], label='Training Accuracy')
axs[0, 1].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0, 1].set_title('Accuracy over Epochs')
axs[0, 1].set_xlabel('Epochs')
axs[0, 1].set_ylabel('Accuracy')
axs[0, 1].set_ylim(0, 1)  # Corrected from axs[0, 0] to axs[0, 1]
axs[0, 1].legend()

# Plot the Dice Coefficient curve
axs[1, 0].plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
axs[1, 0].plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
axs[1, 0].set_title('Dice Coefficient over Epochs')
axs[1, 0].set_xlabel('Epochs')
axs[1, 0].set_ylabel('Dice Coefficient')
axs[1, 0].legend()

# Plot the IoU curve
axs[1, 1].plot(history.history['iou'], label='Training IoU')
axs[1, 1].plot(history.history['val_iou'], label='Validation IoU')
axs[1, 1].set_title('IoU over Epochs')
axs[1, 1].set_xlabel('Epochs')
axs[1, 1].set_ylabel('IoU')
axs[1, 1].legend()

# Adjust spacing between subplots
plt.tight_layout()
plt.show()

# %%
# Predictions on a validation set
predictions = model.predict(images_val)
predictions = (predictions > 0.5).astype(np.uint8)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step

# %%
# Visualize a few results
n = 5  # Number of examples to display
plt.figure(figsize=(15, 15))

for i in range(n):
    # Input image
    plt.subplot(n, 3, i * 3 + 1)
    plt.imshow(images_val[i+1].reshape(128, 128), cmap='gray')
    plt.title('Input Image', fontsize=10)
    plt.axis('off')

    # Ground truth mask
    plt.subplot(n, 3, i * 3 + 2)
    plt.imshow(masks_val[i+1].reshape(128, 128), cmap='gray')
    plt.title('Ground Truth Mask', fontsize=10)
    plt.axis('off')

    # Predicted mask
    plt.subplot(n, 3, i * 3 + 3)
    plt.imshow(predictions[i+1].reshape(128, 128), cmap='gray')
    plt.title('Predicted Mask', fontsize=10)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Path to the test dataset
test_dir = '/kaggle/input/brain-tumor-classification-mri/Training'

# Load two images from each class for testing
test_images = []
test_labels = []

for class_name in classes:
    class_folder = os.path.join(test_dir, class_name)
    
    # Get the names of the test images
    image_names = os.listdir(class_folder)
    
    # Ensure there are at least 2 images
    if len(image_names) >= 2:
        for image_name in image_names[:2]:  # Take the first two images from each class
            image_path = os.path.join(class_folder, image_name)
            
            # Load and preprocess the image
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
            image = cv2.resize(image, target_size)
            image = image / 255.0
            image = np.expand_dims(image, axis=-1)  # Add the channel dimension
            
            test_images.append(image)
            test_labels.append(class_name)

# Convert to a NumPy array
test_images = np.array(test_images)

# Make predictions on these new images
test_predictions = model.predict(test_images)
test_predictions = (test_predictions > 0.5).astype(np.uint8)

# Initialize the figure with a grid for each class
fig, axs = plt.subplots(len(classes) + 1, 5, figsize=(15, 10), 
                         gridspec_kw={'width_ratios': [0.5, 4, 4, 4, 4], 'height_ratios': [0.5] + [4]*len(classes)})

# Column titles
titles = ["Class", "Image", "Predicted Mask", "Image", "Predicted Mask"]
for j in range(5):
    axs[0, j].text(0.5, 0.5, titles[j], fontsize=10, ha='center', va='center', fontweight='bold')
    axs[0, j].axis('off')

# Display the images and their predictions
for i, class_name in enumerate(classes):
    class_indices = [j for j, label in enumerate(test_labels) if label == class_name]
    
    if len(class_indices) >= 2:  # Check if there are at least 2 indices for the class
        example_index1 = class_indices[0]
        example_index2 = class_indices[1]

        # Display the class name
        axs[i + 1, 0].text(0.5, 0.5, class_name, fontsize=10, ha='center', va='center', fontweight='bold')
        axs[i + 1, 0].axis('off')  # Remove the axes
        
        # Display the first image
        axs[i + 1, 1].imshow(test_images[example_index1].squeeze(), cmap='gray')
        axs[i + 1, 1].axis('off')  # Remove the axes

        # Display the predicted mask for the first image
        axs[i + 1, 2].imshow(test_predictions[example_index1], cmap='gray')
        axs[i + 1, 2].axis('off')  # Remove the axes

        # Display the second image
        axs[i + 1, 3].imshow(test_images[example_index2].squeeze(), cmap='gray')
        axs[i + 1, 3].axis('off')  # Remove the axes

        # Display the predicted mask for the second image
        axs[i + 1, 4].imshow(test_predictions[example_index2], cmap='gray')
        axs[i + 1, 4].axis('off')  # Remove the axes

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
